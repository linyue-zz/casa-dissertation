# %%
import pandas as pd

# %% [markdown]
# ## Prepare for Raw Variables

# %% [markdown]
# ### Sptial units

# %%
#read in 2011 MSOA and the corresponding Local Authority & Region for Southwest England (SW) and London
msoa_sw_2011 = pd.read_csv('data00/msoa_sw_2011.csv')
msoa_london_2011 = pd.read_csv('data00/msoa_london_2011.csv')

# %%
msoa_sw_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MSOA11CD  229 non-null    object
#  1   MSOA11NM  229 non-null    object
#  2   LAD11CD   229 non-null    object
#  3   LAD11NM   229 non-null    object
#  4   RGN11CD   229 non-null    object
#  5   RGN11NM   229 non-null    object
# dtypes: object(6)
# memory usage: 10.9+ KB

# %%
msoa_london_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 983 entries, 0 to 982
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MSOA11CD  983 non-null    object
#  1   MSOA11NM  983 non-null    object
#  2   LAD11CD   983 non-null    object
#  3   LAD11NM   983 non-null    object
#  4   RGN11CD   983 non-null    object
#  5   RGN11NM   983 non-null    object
# dtypes: object(6)
# memory usage: 46.2+ KB

# %%
#read in the lookup sheet between 2001 MSOA and 2011 MSOA
mosa_01to11=pd.read_csv('data00/MSOA_2001_to_2011.csv')

# %%
#add the corresponding 2001 MSOA for SW and London
sw0 = msoa_sw_2011.merge(mosa_01to11, on='MSOA11CD', how='left')
london0 = msoa_london_2011.merge(mosa_01to11, on='MSOA11CD', how='left')

# %%
sw0.isnull().values.any()
# Out:
# False

# %%
london0.isnull().values.any()
# Out:
# True

# %%
london0[london0.isna().any(axis=1)]
# Out:
#       MSOA11CD       MSOA11NM    LAD11CD    LAD11NM    RGN11CD RGN11NM  \
# 959  E02006928  Greenwich 035  E09000011  Greenwich  E12000007  London
#
#     MSOA01CD MSOA01NM CHGIND
# 959      NaN      NaN    NaN

# %%
london0 = london0.drop(labels=959, axis=0)
london0 = london0.reset_index(drop=True)

# %%
london0.isnull().values.any()
# Out:
# False

# %%
sw0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 230 entries, 0 to 229
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MSOA11CD  230 non-null    object
#  1   MSOA11NM  230 non-null    object
#  2   LAD11CD   230 non-null    object
#  3   LAD11NM   230 non-null    object
#  4   RGN11CD   230 non-null    object
#  5   RGN11NM   230 non-null    object
#  6   MSOA01CD  230 non-null    object
#  7   MSOA01NM  230 non-null    object
#  8   CHGIND    230 non-null    object
# dtypes: object(9)
# memory usage: 18.0+ KB

# %%
london0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MSOA11CD  986 non-null    object
#  1   MSOA11NM  986 non-null    object
#  2   LAD11CD   986 non-null    object
#  3   LAD11NM   986 non-null    object
#  4   RGN11CD   986 non-null    object
#  5   RGN11NM   986 non-null    object
#  6   MSOA01CD  986 non-null    object
#  7   MSOA01NM  986 non-null    object
#  8   CHGIND    986 non-null    object
# dtypes: object(9)
# memory usage: 69.5+ KB

# %%
sw0.groupby(['CHGIND']).size()
# Out:
# CHGIND
# M      2
# U    228
# dtype: int64

# %%
london0.groupby(['CHGIND']).size()
# Out:
# CHGIND
# M      8
# S      6
# U    951
# X     21
# dtype: int64

# %% [markdown]
# Please notice the change in the number of rows after merging. The reason is that some 2001 MSOAs are merged into one in 2011 MSOA and some 2001 MSOAs are split into two into 2011 MSOAs. In column 'CHGIND', M means several 2001 MSOAs are merged into one 2011 MSOA; S means one 2001 MSOA are split into several 2011 MSOAs. Since the analysis will be made based on 2011 MSOA, only the rows whose 'CHGIND' value is M should take special care of. To facilitate the data processing process, I decided to first combine the sw and london dataset.

# %%
#combine sw and london dataset into one to facilitate the data processing.
swandlondon0 = pd.concat([sw0, london0],ignore_index=True)

# %%
swandlondon0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1216 entries, 0 to 1215
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MSOA11CD  1216 non-null   object
#  1   MSOA11NM  1216 non-null   object
#  2   LAD11CD   1216 non-null   object
#  3   LAD11NM   1216 non-null   object
#  4   RGN11CD   1216 non-null   object
#  5   RGN11NM   1216 non-null   object
#  6   MSOA01CD  1216 non-null   object
#  7   MSOA01NM  1216 non-null   object
#  8   CHGIND    1216 non-null   object
# dtypes: object(9)
# memory usage: 85.6+ KB

# %% [markdown]
# ### Socio-demographics and Build Environment Data

# %% [markdown]
# #### House Price Data

# %%
#read in median house price of 2001 and 2011 for all MSOAs
medianprice_2011 = pd.read_csv('data01/median_price_2011.csv')
medianprice_2001 = pd.read_csv('data01/median_price_2001.csv')
#read in median house price of 2001 and 2011 for all local authorities 
medianprice_la = pd.read_csv('data01/median_price_la.csv')
#read in median house price of 2001 and 2011 for all regions 
medianprice_r = pd.read_csv('data01/median_price_reigion.csv')

# %% [markdown]
# #### Income Data (lack of 2001 MSOA level data)

# %%
#read in mean income of 2011 for all MSOAs
meanincome_2011 = pd.read_csv('data01/mean_earning_2011.csv')
#read in mean income of 2001 and 2011 for all local authorities
meanincome_la = pd.read_csv('data01/mean_earning_la.csv')
#read in mean income of 2001 and 2011 for all regions
meanincome_r = pd.read_csv('data01/mean_earning_region.csv')

# %% [markdown]
# #### NS-SeC Data (occupation condition)

# %%
#read in NS-SeC data of 2001 and 2011 for all MSOAs
nssec_2011 = pd.read_csv('data01/NS-SeC_2011.csv')
nssec_2001 = pd.read_csv('data01/NS-SeC_2001.csv')
#read in NS-SeC data of 2001 and 2011 for all local authorities 
nssec_2011_la = pd.read_csv('data01/NS-SeC_2011_la.csv')
nssec_2001_la = pd.read_csv('data01/NS-SeC_2001_la.csv')
#read in NS-SeC data of 2001 and 2011 for all regions 
nssec_2011_r = pd.read_csv('data01/NS-SeC_2011_region.csv')
nssec_2001_r = pd.read_csv('data01/NS-SeC_2001_region.csv')

# %% [markdown]
# #### Qualification Data

# %%
#read in qualification data of 2001 and 2011 for all MSOAs
qualification_2011 = pd.read_csv('data01/qualification_2011.csv')
qualification_2001 = pd.read_csv('data01/qualification_2001.csv')
#read in qualification data of 2001 and 2011 for all local authorities 
qualification_2011_la = pd.read_csv('data01/qualifications_2011_la.csv')
qualification_2001_la = pd.read_csv('data01/qualifications_2001_la.csv')
#read in qualification data of 2001 and 2011 for all regions 
qualification_2011_r = pd.read_csv('data01/qualifications_2011_region.csv')
qualification_2001_r = pd.read_csv('data01/qualifications_2001_region.csv')

# %% [markdown]
# #### Household Space Data (vacant ones are represented for the level of second homes)

# %%
#read in Household Space Data of 2001 and 2011 for all MSOAs
space_2001 = pd.read_csv('data02/householdspace_2001.csv')
space_2011 = pd.read_csv('data02/householdspace_2011.csv')
#read in Household Space Data of 2001 and 2011 for all local authorities
space_2001_la = pd.read_csv('data02/householdspace_2001_la.csv')
space_2011_la = pd.read_csv('data02/householdspace_2011_la.csv')

# %% [markdown]
# #### Household Component Data (mainly focus on the children)

# %%
#read in Household Component Data of 2001 and 2011 for all MSOAs
children_2001 = pd.read_csv('data03/children_2001.csv')
children_2011 = pd.read_csv('data03/children_2011.csv')
#read in Household Component Data of 2001 and 2011 for all local authorities
children_2001_la = pd.read_csv('data03/children_2001_la.csv')
children_2011_la = pd.read_csv('data03/children_2011_la.csv')

# %% [markdown]
# #### Economic Activty Data (mainly focus on the retired population)

# %%
#read in Economic Activty Data of 2001 and 2011 for all MSOAs
eco_2001 = pd.read_csv('data03/economic_activity_2001.csv')
eco_2011 = pd.read_csv('data03/economic_activity_2011.csv')
#read in Economic Activty Data of 2001 and 2011 for all local authorities
eco_2001_la = pd.read_csv('data03/economic_activity_2001_la.csv')
eco_2011_la = pd.read_csv('data03/economic_activity_2011_la.csv')

# %% [markdown]
# #### Migration Data (lack of Migration data of 2001 for MSOA level)

# %%
#read in Migration Data of 2001 and 2011 for all MSOAs
migration_2011 = pd.read_csv('data03/migration_2011.csv')
#read in Migaration Data of 2001 and 2011 for all local authorities
migration_2001_la = pd.read_csv('data03/migration_2001_la.csv')
migration_2011_la = pd.read_csv('data03/migration_2011_la.csv')

# %% [markdown]
# #### Residential Property Sale Data

# %%
#read in Residential Property Sale Data of 2001 and 2011 for all MSOAs
sale= pd.read_csv('data03/residential_property_sale.csv')
#read in Residential Property Sale Data of 2001 and 2011 for all local authorities
sale_la = pd.read_csv('data03/residential_property_sale_la.csv')

# %% [markdown]
# #### Tenure Data

# %%
#read in Tenure Data of 2001 and 2011 for all MSOAs
tenure_2001 = pd.read_csv('data03/tenure_2001.csv')
tenure_2011 = pd.read_csv('data03/tenure_2011.csv')
#read in Tenure Data of 2001 and 2011 for all local authorities
tenure_2001_la = pd.read_csv('data03/tenure_2001_la.csv')
tenure_2011_la = pd.read_csv('data03/tenure_2011_la.csv')

# %% [markdown]
# Merge all demographic and housing data to the 'swandlondon0' dataset

# %%
swandlondon0 = swandlondon0.merge(medianprice_2001, on='MSOA11CD', how='left')
swandlondon0 = swandlondon0.merge(medianprice_2011, on='MSOA11CD', how='left')
swandlondon0 = swandlondon0.merge(medianprice_la, on='LAD11CD', how='left')
swandlondon0 = swandlondon0.merge(medianprice_r, on='RGN11CD', how='left')

# %%
swandlondon0 = swandlondon0.merge(meanincome_2011, on='MSOA11CD', how='left')
swandlondon0 = swandlondon0.merge(meanincome_la, on='LAD11CD', how='left')
swandlondon0 = swandlondon0.merge(meanincome_r, on='RGN11NM', how='left')

# %%
swandlondon0 = swandlondon0.merge(nssec_2001, on='MSOA01CD', how='left')
swandlondon0 = swandlondon0.merge(nssec_2011, on='MSOA11CD', how='left')
swandlondon0 = swandlondon0.merge(nssec_2001_la, on='LAD11NM', how='left')
swandlondon0 = swandlondon0.merge(nssec_2011_la, on='LAD11NM', how='left')
swandlondon0 = swandlondon0.merge(nssec_2001_r, on='RGN11NM', how='left')
swandlondon0 = swandlondon0.merge(nssec_2011_r, on='RGN11NM', how='left')
swandlondon0 = swandlondon0.merge(qualification_2001, on='MSOA01CD', how='left')
swandlondon0 = swandlondon0.merge(qualification_2011, on='MSOA11CD', how='left')
swandlondon0 = swandlondon0.merge(qualification_2001_la, on='LAD11NM', how='left')
swandlondon0 = swandlondon0.merge(qualification_2011_la, on='LAD11NM', how='left')
swandlondon0 = swandlondon0.merge(qualification_2001_r, on='RGN11NM', how='left')
swandlondon0 = swandlondon0.merge(qualification_2011_r, on='RGN11NM', how='left')

# %%
swandlondon0 = swandlondon0.merge(space_2001, on='MSOA01CD', how='left')
swandlondon0 = swandlondon0.merge(space_2011, on='MSOA11CD', how='left')
swandlondon0 = swandlondon0.merge(space_2001_la, on='LAD11CD', how='left')
swandlondon0 = swandlondon0.merge(space_2011_la, on='LAD11CD', how='left')

# %%
swandlondon0 = swandlondon0.merge(children_2001, on='MSOA01CD', how='left')
swandlondon0 = swandlondon0.merge(children_2011, on='MSOA11CD', how='left')
swandlondon0 = swandlondon0.merge(children_2001_la, on='LAD11NM', how='left')
swandlondon0 = swandlondon0.merge(children_2011_la, on='LAD11NM', how='left')

# %%
swandlondon0 = swandlondon0.merge(eco_2001, on='MSOA01CD', how='left')
swandlondon0 = swandlondon0.merge(eco_2011, on='MSOA11CD', how='left')
swandlondon0 = swandlondon0.merge(eco_2001_la, on='LAD11NM', how='left')
swandlondon0 = swandlondon0.merge(eco_2011_la, on='LAD11NM', how='left')

# %%
swandlondon0 = swandlondon0.merge(migration_2011, on='MSOA11CD', how='left')
swandlondon0 = swandlondon0.merge(migration_2001_la, on='LAD11NM', how='left')
swandlondon0 = swandlondon0.merge(migration_2011_la, on='LAD11NM', how='left')

# %%
swandlondon0 = swandlondon0.merge(sale, on='MSOA11CD', how='left')
swandlondon0 = swandlondon0.merge(sale_la, on='LAD11CD', how='left')

# %%
swandlondon0 = swandlondon0.merge(tenure_2001, on='MSOA01CD', how='left')
swandlondon0 = swandlondon0.merge(tenure_2011, on='MSOA11CD', how='left')
swandlondon0 = swandlondon0.merge(tenure_2001_la, on='LAD11NM', how='left')
swandlondon0 = swandlondon0.merge(tenure_2011_la, on='LAD11NM', how='left')

# %%
swandlondon0.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1216 entries, 0 to 1215
# Data columns (total 157 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   MSOA11CD                           object
#  1   MSOA11NM                           object
#  2   LAD11CD                            object
#  3   LAD11NM                            object
#  4   RGN11CD                            object
#  5   RGN11NM                            object
#  6   MSOA01CD                           object
#  7   MSOA01NM                           object
#  8   CHGIND                             object
#  9   median_price_2001                  float64
#  10  median_price_2011                  object
#  11  median_price_2001_la               int64
#  12  median_price_2011_la               int64
#  13  median_price_2001_region           int64
#  14  median_price_2011_region           int64
#  15  earnings_2011                      float64
#  16  earnings_2001_la                   int64
#  17  earnings_2011_la                   float64
#  18  earnings_2001_region               int64
#  19  earnings_2011_region               int64
#  20  NS-SeC_all_2001                    int64
#  21  NS-SeC_higher_2001                 int64
#  22  NS-SeC_higher_2001_pct             float64
#  23  NS-SeC_all_2011                    object
#  24  NS-SeC_higher_2011                 float64
#  25  NS-SeC_higher_2011_pct             float64
#  26  NS-SeC_all_2001_la                 int64
#  27  NS-SeC_higher_2001_la              int64
#  28  NS-SeC_higher_2001_la_pct          float64
#  29  NS-SeC_all_2011_la                 int64
#  30  NS-SeC_higher_2011_la              int64
#  31  NS-SeC_higher_2011_la_pct          float64
#  32  NS-SeC_all_2001_region             int64
#  33  NS-SeC_higher_2001_region          int64
#  34  NS-SeC_higher_2001_region_pct      float64
#  35  NS-SeC_all_2011_region             int64
#  36  NS-SeC_higher_2011_region          int64
#  37  NS-SeC_higher_2011_region_pct      float64
#  38  qualification_all_2001             object
#  39  qualification_2001                 float64
#  40  qualification_2001_pct             float64
#  41  qualification_all_2011             object
#  42  qualification_2011                 float64
#  43  qualification_2011_pct             float64
#  44  qualification_all_2001_la          int64
#  45  qualification_2001_la              int64
#  46  qualification_2001_la_pct          float64
#  47  qualification_all_2011_la          int64
#  48  qualification_2011_la              int64
#  49  qualification_2011_la_pct          float64
#  50  qualification_all_2001_region      int64
#  51  qualification_2001_region          int64
#  52  qualification_2001_region_pct      float64
#  53  qualification_all_2011_region      int64
#  54  qualification_2011_region          int64
#  55  qualification_2011_region_pct      float64
#  56  space_all_2001                     int64
#  57  space_vacant_2001                  int64
#  58  space_vacant_2001_pct              float64
#  59  space_all_2011                     int64
#  60  space_vacant_2011                  int64
#  61  space_vacant_2011_pct              float64
#  62  space_all_2001_la                  int64
#  63  space_vacant_2001_la               int64
#  64  space_vacant_2001_la_pct           float64
#  65  space_all_2011_la                  int64
#  66  space_vacant_2011_la               int64
#  67  space_vacant_2011_la_pct           float64
#  68  all_households_2001                object
#  69  no_children_2001                   float64
#  70  dependent_children_2001            float64
#  71  nondependent_children_2001         float64
#  72  no_children_2001_pct               float64
#  73  dependent_children_2001_pct        float64
#  74  nondependent_children_2001_pct     float64
#  75  all_households_2011                object
#  76  no_children_2011                   float64
#  77  dependent_children_2011            float64
#  78  nondependent_children_2011         float64
#  79  no_children_2011_pct               float64
#  80  dependent_children_2011_pct        float64
#  81  nondependent_children_2011_pct     float64
#  82  all_households_2001_la             object
#  83  no_children_2001_la                float64
#  84  dependent_children_2001_la         float64
#  85  nondependent_children_2001_la      float64
#  86  no_children_2001_la_pct            float64
#  87  dependent_children_2001_la_pct     float64
#  88  nondependent_children_2001_la_pct  float64
#  89  all_households_2011_la             object
#  90  no_children_2011_la                float64
#  91  dependent_children_2011_la         float64
#  92  nondependent_children_2011_la      float64
#  93  no_children_2011_la_pct            float64
#  94  dependent_children_2011_la_pct     float64
#  95  nondependent_children_2011_la_pct  float64
#  96  economically_inactive_2001         int64
#  97  retired_2001                       int64
#  98  student_2001                       int64
#  99  retired_2001_pct                   float64
#  100 student_2001_pct                   float64
#  101 economically_inactive_2011         int64
#  102 retired_2011                       int64
#  103 student_2011                       int64
#  104 retired_2011_pct                   float64
#  105 student_2011_pct                   float64
#  106 economically_inactive_2001_la      float64
#  107 retired_2001_la                    float64
#  108 student_2001_la                    float64
#  109 retired_2001_la_pct                float64
#  110 student_2001_la_pct                float64
#  111 economically_inactive_2011_la      float64
#  112 retired_2011_la                    float64
#  113 student_2011_la                    float64
#  114 retired_2011_la_pct                float64
#  115 student_2011_la_pct                float64
#  116 residents_all_2011                 int64
#  117 migrants_2011                      int64
#  118 migrants_2011_pct                  float64
#  119 residents_all_2001_la              object
#  120 migrants_2001_la                   object
#  121 migrants_2001_la_pct               object
#  122 residents_all_2011_la              float64
#  123 migrants_2011_la                   float64
#  124 migrants_2011_la_pct               float64
#  125 residential_sale_2001              int64
#  126 residential_sale_2011              int64
#  127 newlybuilt_sale_2001               int64
#  128 newlybuilt_sale_2011               int64
#  129 newlybuilt_sale_2001_pct           float64
#  130 newlybuilt_sale_2011_pct           float64
#  131 residential_sale_2001_la           int64
#  132 residential__sale_2011_la          int64
#  133 newlybuilt_sale_2001_la            int64
#  134 newlybuilt_sale_2011_la            int64
#  135 newlybuilt_sale_2001_la_pct        float64
#  136 newlybuilt_sale_2011_la_pct        float64
#  137 tenure_all_2001                    object
#  138 owned_2001                         float64
#  139 rented_2001                        float64
#  140 owned_2001_pct                     float64
#  141 rented_2001_pct                    float64
#  142 tenure_all_2011                    object
#  143 owned_2011                         float64
#  144 rented_2011                        float64
#  145 owned_2011_pct                     float64
#  146 rented_2011_pct                    float64
#  147 tenure_all_2001_la                 float64
#  148 owned_2001_la                      float64
#  149 rented_2001_la                     float64
#  150 owned_2001_la_pct                  float64
#  151 rented_2001_la_pct                 float64
#  152 tenure_all_2011_la                 object
#  153 owned_2011_la                      float64
#  154 rented_2011_la                     float64
#  155 owned_2011_la_pct                  float64
#  156 rented_2011_la_pct                 float64
# dtypes: float64(85), int64(49), object(23)
# memory usage: 1.5+ MB

# %%
#extract the rows whose 'CHGING' value is M. The percentage value of the 2001 variables of these rows should be recalculated
swandlondon0_sub1=swandlondon0[(swandlondon0['CHGIND']=='X')|(swandlondon0['CHGIND']=='U')|(swandlondon0['CHGIND']=='S')].copy()
swandlondon0_subm=swandlondon0[swandlondon0['CHGIND']=='M'].copy()

# %%
swandlondon0_sub1.info()
swandlondon0_subm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1206 entries, 0 to 1215
# Columns: 157 entries, MSOA11CD to rented_2011_la_pct
# dtypes: float64(85), int64(49), object(23)
# memory usage: 1.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 228 to 1205
# Columns: 157 entries, MSOA11CD to rented_2011_la_pct
# dtypes: float64(85), int64(49), object(23)
# memory usage: 12.3+ KB

# %%
swandlondon0_subm.head(10)
# Out:
#        MSOA11CD       MSOA11NM    LAD11CD    LAD11NM    RGN11CD     RGN11NM  \
# 228   E02006840     Torbay 019  E06000027     Torbay  E12000009  South West
# 229   E02006840     Torbay 019  E06000027     Torbay  E12000009  South West
# 1183  E02006924  Redbridge 035  E09000026  Redbridge  E12000007      London
# 1184  E02006924  Redbridge 035  E09000026  Redbridge  E12000007      London
# 1185  E02006925  Redbridge 036  E09000026  Redbridge  E12000007      London
# 1186  E02006925  Redbridge 036  E09000026  Redbridge  E12000007      London
# 1187  E02006927  Greenwich 034  E09000011  Greenwich  E12000007      London
# 1188  E02006927  Greenwich 034  E09000011  Greenwich  E12000007      London
# 1204  E02006882     Harrow 033  E09000015     Harrow  E12000007      London
# 1205  E02006882     Harrow 033  E09000015     Harrow  E12000007      London
#
#        MSOA01CD       MSOA01NM CHGIND  median_price_2001  ...  \
# 228   E02003160     Torbay 007      M            84500.0  ...
# 229   E02003162     Torbay 009      M            84500.0  ...
# 1183  E02000771  Redbridge 021      M           165000.0  ...
# 1184  E02000775  Redbridge 025      M           165000.0  ...
# 1185  E02000761  Redbridge 011      M           185000.0  ...
# 1186  E02000766  Redbridge 016      M           185000.0  ...
# 1187  E02000336  Greenwich 024      M           127500.0  ...
# 1188  E02000338  Greenwich 026      M           127500.0  ...
# 1204  E02000450     Harrow 018      M           182250.0  ...
# 1205  E02000446     Harrow 014      M           182250.0  ...
#
#      tenure_all_2001_la  owned_2001_la  rented_2001_la  owned_2001_la_pct  \
# 228             57420.0        41907.0         13403.0           0.729833
# 229             57420.0        41907.0         13403.0           0.729833
# 1183            92288.0        69008.0         20480.0           0.747746
# 1184            92288.0        69008.0         20480.0           0.747746
# 1185            92288.0        69008.0         20480.0           0.747746
# 1186            92288.0        69008.0         20480.0           0.747746
# 1187            92788.0        44870.0         44929.0           0.483575
# 1188            92788.0        44870.0         44929.0           0.483575
# 1204            79112.0        58755.0         17113.0           0.742681
# 1205            79112.0        58755.0         17113.0           0.742681
#
#       rented_2001_la_pct  tenure_all_2011_la  owned_2011_la  rented_2011_la  \
# 228             0.233420               59010        39424.0         18458.0
# 229             0.233420               59010        39424.0         18458.0
# 1183            0.221914               99105        62983.0         33946.0
# 1184            0.221914               99105        62983.0         33946.0
# 1185            0.221914               99105        62983.0         33946.0
# 1186            0.221914               99105        62983.0         33946.0
# 1187            0.484211              101045        43719.0         54666.0
# 1188            0.484211              101045        43719.0         54666.0
# 1204            0.216314               84268        55001.0         27247.0
# 1205            0.216314               84268        55001.0         27247.0
#
#       owned_2011_la_pct  rented_2011_la_pct
# 228            0.668090            0.312794
# 229            0.668090            0.312794
# 1183           0.635518            0.342526
# 1184           0.635518            0.342526
# 1185           0.635518            0.342526
# 1186           0.635518            0.342526
# 1187           0.432669            0.541006
# 1188           0.432669            0.541006
# 1204           0.652691            0.323337
# 1205           0.652691            0.323337
#
# [10 rows x 157 columns]

# %%
#for the rows whose 'CHGING' value is M, recalculation is carred out seperately in Excel
swandlondon0_subm.to_csv('output/swandlondon0_subm.csv',index=False)

# %%
#read in th the dataset after recalulation and compare it with the original one.
swandlondon0_subm_after = pd.read_csv('output/swandlondon0_subm_after.csv')

# %%
pd.set_option("display.max_columns", None)
swandlondon0_subm_after.head(5)
# Out:
#     MSOA11CD       MSOA11NM    LAD11CD    LAD11NM    RGN11CD     RGN11NM  \
# 0  E02006840     Torbay 019  E06000027     Torbay  E12000009  South West
# 1  E02006924  Redbridge 035  E09000026  Redbridge  E12000007      London
# 2  E02006925  Redbridge 036  E09000026  Redbridge  E12000007      London
# 3  E02006927  Greenwich 034  E09000011  Greenwich  E12000007      London
# 4  E02006882     Harrow 033  E09000015     Harrow  E12000007      London
#
#     MSOA01CD       MSOA01NM CHGIND  median_price_2001  median_price_2011  \
# 0  E02003160     Torbay 007      M              84500             180000
# 1  E02000771  Redbridge 021      M             165000             325000
# 2  E02000761  Redbridge 011      M             185000             326750
# 3  E02000336  Greenwich 024      M             127500             280000
# 4  E02000450     Harrow 018      M             182250             315000
#
#    median_price_2001_la  median_price_2011_la  median_price_2001_region  \
# 0                 82500                160000                     96500
# 1                138500                250000                    155000
# 2                138500                250000                    155000
# 3                124995                249995                    155000
# 4                166000                294500                    155000
#
#    median_price_2011_region  earnings_2011  earnings_2001_la  \
# 0                    185000       14913.78             11300
# 1                    292688       14867.94             13804
# 2                    292688       16547.20             13804
# 3                    292688       19259.60             15592
# 4                    292688       15160.69             16118
# 3                        5300332                    1642467
# 4                        5300332                    1642467
#
#    qualification_2001_region_pct  qualification_all_2011_region  \
# 0                       0.188394                        4359257
# 1                       0.309880                        6549173
# 2                       0.309880                        6549173
# 3                       0.309880                        6549173
# 4                       0.309880                        6549173
#
#    qualification_2011_region  qualification_2011_region_pct  space_all_2001  \
# 0                    1193337                       0.273748            4744
# 1                    2470225                       0.377181            4213
# 2                    2470225                       0.377181            4190
# 3                    2470225                       0.377181            5030
# 4                    2470225                       0.377181            4334
#
#    space_vacant_2001  space_vacant_2001_pct  space_all_2011  \
# 0                141               0.029722            4806
# 1                119               0.028246            4121
# 2                 54               0.012888            4181
# 3                 78               0.015507            3449
# 4                 84               0.019382            4403
#
#    space_vacant_2011  space_vacant_2011_pct  space_all_2001_la  \
# 0                305               0.063462              60479
# 1                101               0.024509              94174
# 2                 79               0.018895              94174
# 3                111               0.032183              95835
# 4                 61               0.013854              80904
#
#    space_vacant_2001_la  space_vacant_2001_la_pct  space_all_2011_la  \
# 0                  3059                  0.050580              64370
# 1                  1886                  0.020027             101575
# 2                  1886                  0.020027             101575
# 3                  3047                  0.031794             103827
# 4                  1792                  0.022150              86667
#
#    space_vacant_2011_la  space_vacant_2011_la_pct  all_households_2001  \
# 0                  5360                  0.083269                 4601
# 1                  2470                  0.024317                 4094
# 2                  2470                  0.024317                 4139
# 3                  2782                  0.026795                 4951
# 4                  2399                  0.027681                 4250
#
#    no_children_2001  dependent_children_2001  nondependent_children_2001  \
# 0               827                     1245                         361
# 1               477                     1103                         532
# 2               506                     1337                         657
# 3               589                     1375                         435
# 4               478                     1458                         653
#
#    no_children_2001_pct  dependent_children_2001_pct  \
# 0              0.179744                     0.270593
# 1              0.116512                     0.269419
# 2              0.122252                     0.323025
# 3              0.118966                     0.277722
# 4              0.112471                     0.343059
#
#    nondependent_children_2001_pct  all_households_2011  no_children_2011  \
# 0                        0.078461                 4501               816
# 1                        0.129946                 4020               371
# 2                        0.158734                 4102               362
# 3                        0.087861                 3338               441
# 4                        0.153647                 4342               461
#
#    dependent_children_2011  nondependent_children_2011  no_children_2011_pct  \
# 0                     1162                         409              0.181293
# 1                     1111                         562              0.092289
# 2                     1356                         657              0.088250
# 3                      894                         378              0.132115
# 4                     1195                         825              0.106172
#
#    dependent_children_2011_pct  nondependent_children_2011_pct  \
# 0                     0.258165                        0.090869
# 1                     0.276368                        0.139801
# 2                     0.330570                        0.160166
# 3                     0.267825                        0.113241
# 4                     0.275219                        0.190005
#
#    all_households_2001_la  no_children_2001_la  dependent_children_2001_la  \
# 0                   57420                10011                       14158
# 1                   92288                12434                       28403
# 2                   92288                12434                       28403
# 3                   92788                11786                       26372
# 4                   79112                10962                       23941
#
#    nondependent_children_2001_la  no_children_2001_la_pct  \
# 0                           4374                 0.174347
# 1                          10352                 0.134730
# 2                          10352                 0.134730
# 3                           8185                 0.127021
# 4                           9294                 0.138563
#
#    dependent_children_2001_la_pct  nondependent_children_2001_la_pct  \
# 0                        0.246569                           0.076176
# 1                        0.307765                           0.112171
# 2                        0.307765                           0.112171
# 3                        0.284218                           0.088212
# 4                        0.302622                           0.117479
#
#    all_households_2011_la  no_children_2011_la  dependent_children_2011_la  \
# 0                   59010                10580                       13192
# 1                   99105                11804                       31272
# 2                   99105                11804                       31272
# 3                  101045                13402                       28602
# 4                   84268                10341                       24829
#
#    nondependent_children_2011_la  no_children_2011_la_pct  \
# 0                           4850                 0.179292
# 1                          11409                 0.119106
# 2                          11409                 0.119106
# 3                           9200                 0.132634
# 4                          11412                 0.122716
#
#    dependent_children_2011_la_pct  nondependent_children_2011_la_pct  \
# 0                        0.223555                           0.082189
# 1                        0.315544                           0.115120
# 2                        0.315544                           0.115120
# 3                        0.283062                           0.091049
# 4                        0.294643                           0.135425
#
#    economically_inactive_2001  retired_2001  student_2001  retired_2001_pct  \
# 0                        2615          1275           233          0.487572
# 1                        3061           912           712          0.297942
# 2                        2862          1037           620          0.362334
# 3                        2939           874           524          0.297380
# 4                        3072          1012           723          0.329427
#
#    student_2001_pct  economically_inactive_2011  retired_2011  student_2011  \
# 0          0.089101                        2350          1362           269
# 1          0.232604                        3235           951           944
# 2          0.216632                        2955          1002           935
# 3          0.178292                        1891           702           408
# 4          0.235352                        3120          1182           854
#
#    retired_2011_pct  student_2011_pct  economically_inactive_2001_la  \
# 0          0.579574          0.114468                          33322
# 1          0.293972          0.291808                          58007
# 2          0.339086          0.316413                          58007
# 3          0.371232          0.215759                          52759
# 4          0.378846          0.273718                          47465
#
#    retired_2001_la  student_2001_la  retired_2001_la_pct  student_2001_la_pct  \
# 0            16321             2372             0.489797             0.071184
# 1            19389            11009             0.334253             0.189787
# 2            19389            11009             0.334253             0.189787
# 3            15903             9400             0.301427             0.178169
# 4            16913             9474             0.356326             0.199600
#
#    economically_inactive_2011_la  retired_2011_la  student_2011_la  \
# 0                          32205            18416             3032
# 1                          61768            19026            16199
# 2                          61768            19026            16199
# 3                          54649            15695            13957
# 4                          51444            18189            13417
#
#    retired_2011_la_pct  student_2011_la_pct  residents_all_2011  \
# 0             0.571837             0.094147               10636
# 1             0.308024             0.262256               12780
# 2             0.308024             0.262256               13241
# 3             0.287196             0.255394                8315
# 4             0.353569             0.260808               14174
#
#    migrants_2011  migrants_2011_pct  residents_all_2001_la  migrants_2001_la  \
# 0            851           0.080011                 129706              6164
# 1            963           0.075352                 238635             11993
# 2            858           0.064799                 238635             11993
# 3            657           0.079014                 214403             11798
# 4            982           0.069282                 206814              9968
#
#    migrants_2001_la_pct  residents_all_2011_la  migrants_2011_la  \
# 0              0.047523                 130959              4938
# 1              0.050257                 278970             14898
# 2              0.050257                 278970             14898
# 3              0.055027                 254557             16607
# 4              0.048198                 239056             11786
#
#    migrants_2011_la_pct  residential_sale_2001  residential_sale_2011  \
# 0              0.037706                    303                    143
# 1              0.053404                    180                     92
# 2              0.053404                    202                    110
# 3              0.065239                    146                    116
# 4              0.049302                    168                     79
#
#    newlybuilt_sale_2001  newlybuilt_sale_2011  newlybuilt_sale_2001_pct  \
# 0                     4                     8                  0.013201
# 1                     0                     0                  0.000000
# 2                     1                     0                  0.004950
# 3                     0                    12                  0.000000
# 4                     0                     0                  0.000000
#
#    newlybuilt_sale_2011_pct  residential_sale_2001_la  \
# 0                  0.055944                      4417
# 1                  0.000000                      5780
# 2                  0.000000                      5780
# 3                  0.103448                      4839
# 4                  0.000000                      4349
#
#    residential__sale_2011_la  newlybuilt_sale_2001_la  \
# 0                       1977                      272
# 1                       2539                      367
# 2                       2539                      367
# 3                       2570                      899
# 4                       2168                      205
#
#    newlybuilt_sale_2011_la  newlybuilt_sale_2001_la_pct  \
# 0                      146                     0.061580
# 1                       80                     0.063495
# 2                       80                     0.063495
# 3                      422                     0.185782
# 4                      141                     0.047137
#
#    newlybuilt_sale_2011_la_pct  tenure_all_2001  owned_2001  rented_2001  \
# 0                     0.073849             4603        3589          878
# 1                     0.031508             4094        3155          831
# 2                     0.031508             4136        3601          456
# 3                     0.164202             4952        2180         2612
# 4                     0.065037             4250        3528          548
#
#    owned_2001_pct  rented_2001_pct  tenure_all_2011  owned_2011  rented_2011  \
# 0        0.779709         0.190745             4501        3367         1089
# 1        0.770640         0.202980             4020        2748         1220
# 2        0.870648         0.110251             4102        3313          731
# 3        0.440226         0.527464             3338        1924         1352
# 4        0.830118         0.128941             4342        3333          893
#
#    owned_2011_pct  rented_2011_pct  tenure_all_2001_la  owned_2001_la  \
# 0        0.748056         0.241946               57420          41907
# 1        0.683582         0.303483               92288          69008
# 2        0.807655         0.178206               92288          69008
# 3        0.576393         0.405033               92788          44870
# 4        0.767619         0.205666               79112          58755
#
#    rented_2001_la  owned_2001_la_pct  rented_2001_la_pct  tenure_all_2011_la  \
# 0           13403           0.729833            0.233420               59010
# 1           20480           0.747746            0.221914               99105
# 2           20480           0.747746            0.221914               99105
# 3           44929           0.483575            0.484211              101045
# 4           17113           0.742681            0.216314               84268
#
#    owned_2011_la  rented_2011_la  owned_2011_la_pct  rented_2011_la_pct
# 0          39424           18458           0.668090            0.312794
# 1          62983           33946           0.635518            0.342526
# 2          62983           33946           0.635518            0.342526
# 3          43719           54666           0.432669            0.541006
# 4          55001           27247           0.652691            0.323337

# %%
#conbime tow datasets to get the final complete dataset contains all raw data
swandlondon = pd.concat([swandlondon0_sub1, swandlondon0_subm_after],ignore_index=True)

# %%
swandlondon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1211 entries, 0 to 1210
# Columns: 157 entries, MSOA11CD to rented_2011_la_pct
# dtypes: float64(85), int64(49), object(23)
# memory usage: 1.5+ MB

# %%
swandlondon.to_csv('output/swandlondon.csv',index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Create Ratio Variables

# %%
swandlondon = pd.read_csv('output/swandlondon.csv')
swandlondon.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1211 entries, 0 to 1210
# Data columns (total 157 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   MSOA11CD                           object
#  1   MSOA11NM                           object
#  2   LAD11CD                            object
#  3   LAD11NM                            object
#  4   RGN11CD                            object
#  5   RGN11NM                            object
#  6   MSOA01CD                           object
#  7   MSOA01NM                           object
#  8   CHGIND                             object
#  9   median_price_2001                  float64
#  10  median_price_2011                  int64
#  11  median_price_2001_la               int64
#  12  median_price_2011_la               int64
#  13  median_price_2001_region           int64
#  14  median_price_2011_region           int64
#  15  earnings_2011                      float64
#  16  earnings_2001_la                   int64
#  17  earnings_2011_la                   float64
#  18  earnings_2001_region               int64
#  19  earnings_2011_region               int64
#  20  NS-SeC_all_2001                    int64
#  21  NS-SeC_higher_2001                 int64
#  22  NS-SeC_higher_2001_pct             float64
#  23  NS-SeC_all_2011                    int64
#  24  NS-SeC_higher_2011                 float64
#  25  NS-SeC_higher_2011_pct             float64
#  26  NS-SeC_all_2001_la                 int64
#  27  NS-SeC_higher_2001_la              int64
#  28  NS-SeC_higher_2001_la_pct          float64
#  29  NS-SeC_all_2011_la                 int64
#  30  NS-SeC_higher_2011_la              int64
#  31  NS-SeC_higher_2011_la_pct          float64
#  32  NS-SeC_all_2001_region             int64
#  33  NS-SeC_higher_2001_region          int64
#  34  NS-SeC_higher_2001_region_pct      float64
#  35  NS-SeC_all_2011_region             int64
#  36  NS-SeC_higher_2011_region          int64
#  37  NS-SeC_higher_2011_region_pct      float64
#  38  qualification_all_2001             int64
#  39  qualification_2001                 float64
#  40  qualification_2001_pct             float64
#  41  qualification_all_2011             int64
#  42  qualification_2011                 float64
#  43  qualification_2011_pct             float64
#  44  qualification_all_2001_la          int64
#  45  qualification_2001_la              int64
#  46  qualification_2001_la_pct          float64
#  47  qualification_all_2011_la          int64
#  48  qualification_2011_la              int64
#  49  qualification_2011_la_pct          float64
#  50  qualification_all_2001_region      int64
#  51  qualification_2001_region          int64
#  52  qualification_2001_region_pct      float64
#  53  qualification_all_2011_region      int64
#  54  qualification_2011_region          int64
#  55  qualification_2011_region_pct      float64
#  56  space_all_2001                     int64
#  57  space_vacant_2001                  int64
#  58  space_vacant_2001_pct              float64
#  59  space_all_2011                     int64
#  60  space_vacant_2011                  int64
#  61  space_vacant_2011_pct              float64
#  62  space_all_2001_la                  int64
#  63  space_vacant_2001_la               int64
#  64  space_vacant_2001_la_pct           float64
#  65  space_all_2011_la                  int64
#  66  space_vacant_2011_la               int64
#  67  space_vacant_2011_la_pct           float64
#  68  all_households_2001                int64
#  69  no_children_2001                   float64
#  70  dependent_children_2001            float64
#  71  nondependent_children_2001         float64
#  72  no_children_2001_pct               float64
#  73  dependent_children_2001_pct        float64
#  74  nondependent_children_2001_pct     float64
#  75  all_households_2011                int64
#  76  no_children_2011                   float64
#  77  dependent_children_2011            float64
#  78  nondependent_children_2011         float64
#  79  no_children_2011_pct               float64
#  80  dependent_children_2011_pct        float64
#  81  nondependent_children_2011_pct     float64
#  82  all_households_2001_la             int64
#  83  no_children_2001_la                float64
#  84  dependent_children_2001_la         float64
#  85  nondependent_children_2001_la      float64
#  86  no_children_2001_la_pct            float64
#  87  dependent_children_2001_la_pct     float64
#  88  nondependent_children_2001_la_pct  float64
#  89  all_households_2011_la             int64
#  90  no_children_2011_la                float64
#  91  dependent_children_2011_la         float64
#  92  nondependent_children_2011_la      float64
#  93  no_children_2011_la_pct            float64
#  94  dependent_children_2011_la_pct     float64
#  95  nondependent_children_2011_la_pct  float64
#  96  economically_inactive_2001         int64
#  97  retired_2001                       int64
#  98  student_2001                       int64
#  99  retired_2001_pct                   float64
#  100 student_2001_pct                   float64
#  101 economically_inactive_2011         int64
#  102 retired_2011                       int64
#  103 student_2011                       int64
#  104 retired_2011_pct                   float64
#  105 student_2011_pct                   float64
#  106 economically_inactive_2001_la      float64
#  107 retired_2001_la                    float64
#  108 student_2001_la                    float64
#  109 retired_2001_la_pct                float64
#  110 student_2001_la_pct                float64
#  111 economically_inactive_2011_la      float64
#  112 retired_2011_la                    float64
#  113 student_2011_la                    float64
#  114 retired_2011_la_pct                float64
#  115 student_2011_la_pct                float64
#  116 residents_all_2011                 int64
#  117 migrants_2011                      int64
#  118 migrants_2011_pct                  float64
#  119 residents_all_2001_la              int64
#  120 migrants_2001_la                   int64
#  121 migrants_2001_la_pct               float64
#  122 residents_all_2011_la              float64
#  123 migrants_2011_la                   float64
#  124 migrants_2011_la_pct               float64
#  125 residential_sale_2001              int64
#  126 residential_sale_2011              int64
#  127 newlybuilt_sale_2001               int64
#  128 newlybuilt_sale_2011               int64
#  129 newlybuilt_sale_2001_pct           float64
#  130 newlybuilt_sale_2011_pct           float64
#  131 residential_sale_2001_la           int64
#  132 residential__sale_2011_la          int64
#  133 newlybuilt_sale_2001_la            int64
#  134 newlybuilt_sale_2011_la            int64
#  135 newlybuilt_sale_2001_la_pct        float64
#  136 newlybuilt_sale_2011_la_pct        float64
#  137 tenure_all_2001                    int64
#  138 owned_2001                         float64
#  139 rented_2001                        float64
#  140 owned_2001_pct                     float64
#  141 rented_2001_pct                    float64
#  142 tenure_all_2011                    int64
#  143 owned_2011                         float64
#  144 rented_2011                        float64
#  145 owned_2011_pct                     float64
#  146 rented_2011_pct                    float64
#  147 tenure_all_2001_la                 float64
#  148 owned_2001_la                      float64
#  149 rented_2001_la                     float64
#  150 owned_2001_la_pct                  float64
#  151 rented_2001_la_pct                 float64
#  152 tenure_all_2011_la                 int64
#  153 owned_2011_la                      float64
#  154 rented_2011_la                     float64
#  155 owned_2011_la_pct                  float64
#  156 rented_2011_la_pct                 float64
# dtypes: float64(86), int64(62), object(9)
# memory usage: 1.5+ MB

# %%
swandlondon.tail()
# Out:
#        MSOA11CD       MSOA11NM    LAD11CD    LAD11NM    RGN11CD     RGN11NM  \
# 1206  E02006840     Torbay 019  E06000027     Torbay  E12000009  South West
# 1207  E02006924  Redbridge 035  E09000026  Redbridge  E12000007      London
# 1208  E02006925  Redbridge 036  E09000026  Redbridge  E12000007      London
# 1209  E02006927  Greenwich 034  E09000011  Greenwich  E12000007      London
# 1210  E02006882     Harrow 033  E09000015     Harrow  E12000007      London
#
#        MSOA01CD       MSOA01NM CHGIND  median_price_2001  median_price_2011  \
# 1206  E02003160     Torbay 007      M            84500.0             180000
# 1207  E02000771  Redbridge 021      M           165000.0             325000
# 1208  E02000761  Redbridge 011      M           185000.0             326750
# 1209  E02000336  Greenwich 024      M           127500.0             280000
# 1210  E02000450     Harrow 018      M           182250.0             315000
# 1209       1352.0        0.576393         0.405033             92788.0
# 1210        893.0        0.767619         0.205666             79112.0
#
#       owned_2001_la  rented_2001_la  owned_2001_la_pct  rented_2001_la_pct  \
# 1206        41907.0         13403.0           0.729833            0.233420
# 1207        69008.0         20480.0           0.747746            0.221914
# 1208        69008.0         20480.0           0.747746            0.221914
# 1209        44870.0         44929.0           0.483575            0.484211
# 1210        58755.0         17113.0           0.742681            0.216314
#
#       tenure_all_2011_la  owned_2011_la  rented_2011_la  owned_2011_la_pct  \
# 1206               59010        39424.0         18458.0           0.668090
# 1207               99105        62983.0         33946.0           0.635518
# 1208               99105        62983.0         33946.0           0.635518
# 1209              101045        43719.0         54666.0           0.432669
# 1210               84268        55001.0         27247.0           0.652691
#
#       rented_2011_la_pct
# 1206            0.312794
# 1207            0.342526
# 1208            0.342526
# 1209            0.541006
# 1210            0.323337

# %%
# get a list of the column names of all the columns that contain percentage information
pct_cols = [col for col in swandlondon.columns if 'pct' in col]
print(pct_cols)
# Out:
# ['NS-SeC_higher_2001_pct', 'NS-SeC_higher_2011_pct', 'NS-SeC_higher_2001_la_pct', 'NS-SeC_higher_2011_la_pct', 'NS-SeC_higher_2001_region_pct', 'NS-SeC_higher_2011_region_pct', 'qualification_2001_pct', 'qualification_2011_pct', 'qualification_2001_la_pct', 'qualification_2011_la_pct', 'qualification_2001_region_pct', 'qualification_2011_region_pct', 'space_vacant_2001_pct', 'space_vacant_2011_pct', 'space_vacant_2001_la_pct', 'space_vacant_2011_la_pct', 'no_children_2001_pct', 'dependent_children_2001_pct', 'nondependent_children_2001_pct', 'no_children_2011_pct', 'dependent_children_2011_pct', 'nondependent_children_2011_pct', 'no_children_2001_la_pct', 'dependent_children_2001_la_pct', 'nondependent_children_2001_la_pct', 'no_children_2011_la_pct', 'dependent_children_2011_la_pct', 'nondependent_children_2011_la_pct', 'retired_2001_pct', 'student_2001_pct', 'retired_2011_pct', 'student_2011_pct', 'retired_2001_la_pct', 'student_2001_la_pct', 'retired_2011_la_pct', 'student_2011_la_pct', 'migrants_2011_pct', 'migrants_2001_la_pct', 'migrants_2011_la_pct', 'newlybuilt_sale_2001_pct', 'newlybuilt_sale_2011_pct', 'newlybuilt_sale_2001_la_pct', 'newlybuilt_sale_2011_la_pct', 'owned_2001_pct', 'rented_2001_pct', 'owned_2011_pct', 'rented_2011_pct', 'owned_2001_la_pct', 'rented_2001_la_pct', 'owned_2011_la_pct', 'rented_2011_la_pct']

# %%
# get a list of the column names of several columns at the front
front_cols=list(swandlondon.iloc[:,0:20].columns)
print(front_cols)
# Out:
# ['MSOA11CD', 'MSOA11NM', 'LAD11CD', 'LAD11NM', 'RGN11CD', 'RGN11NM', 'MSOA01CD', 'MSOA01NM', 'CHGIND', 'median_price_2001', 'median_price_2011', 'median_price_2001_la', 'median_price_2011_la', 'median_price_2001_region', 'median_price_2011_region', 'earnings_2011', 'earnings_2001_la', 'earnings_2011_la', 'earnings_2001_region', 'earnings_2011_region']

# %%
#get a list of column names to help extract a subdataset contains all the columns that is essential for further analysis
extract_cols=front_cols+pct_cols

# %%
swandlondon_key=swandlondon[extract_cols].copy()

# %%
swandlondon_key.to_csv('output/swandlondon_key.csv',index=False)

# %% [markdown]
# 'swandlondon_key' contains all the raw information

# %%
swandlondon_key.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1211 entries, 0 to 1210
# Data columns (total 71 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   MSOA11CD                           1211 non-null   object
#  1   MSOA11NM                           1211 non-null   object
#  2   LAD11CD                            1211 non-null   object
#  3   LAD11NM                            1211 non-null   object
#  4   RGN11CD                            1211 non-null   object
#  5   RGN11NM                            1211 non-null   object
#  6   MSOA01CD                           1211 non-null   object
#  7   MSOA01NM                           1211 non-null   object
#  8   CHGIND                             1211 non-null   object
#  9   median_price_2001                  1211 non-null   float64
#  10  median_price_2011                  1211 non-null   int64
#  11  median_price_2001_la               1211 non-null   int64
#  12  median_price_2011_la               1211 non-null   int64
#  13  median_price_2001_region           1211 non-null   int64
#  14  median_price_2011_region           1211 non-null   int64
#  15  earnings_2011                      1211 non-null   float64
#  16  earnings_2001_la                   1211 non-null   int64
#  17  earnings_2011_la                   1211 non-null   float64
#  18  earnings_2001_region               1211 non-null   int64
#  19  earnings_2011_region               1211 non-null   int64
#  20  NS-SeC_higher_2001_pct             1211 non-null   float64
#  21  NS-SeC_higher_2011_pct             1211 non-null   float64
#  22  NS-SeC_higher_2001_la_pct          1211 non-null   float64
#  23  NS-SeC_higher_2011_la_pct          1211 non-null   float64
#  24  NS-SeC_higher_2001_region_pct      1211 non-null   float64
#  25  NS-SeC_higher_2011_region_pct      1211 non-null   float64
#  26  qualification_2001_pct             1211 non-null   float64
#  27  qualification_2011_pct             1211 non-null   float64
#  28  qualification_2001_la_pct          1211 non-null   float64
#  29  qualification_2011_la_pct          1211 non-null   float64
#  30  qualification_2001_region_pct      1211 non-null   float64
#  31  qualification_2011_region_pct      1211 non-null   float64
#  32  space_vacant_2001_pct              1211 non-null   float64
#  33  space_vacant_2011_pct              1211 non-null   float64
#  34  space_vacant_2001_la_pct           1211 non-null   float64
#  35  space_vacant_2011_la_pct           1211 non-null   float64
#  36  no_children_2001_pct               1211 non-null   float64
#  37  dependent_children_2001_pct        1211 non-null   float64
#  38  nondependent_children_2001_pct     1211 non-null   float64
#  39  no_children_2011_pct               1211 non-null   float64
#  40  dependent_children_2011_pct        1211 non-null   float64
#  41  nondependent_children_2011_pct     1211 non-null   float64
#  42  no_children_2001_la_pct            1211 non-null   float64
#  43  dependent_children_2001_la_pct     1211 non-null   float64
#  44  nondependent_children_2001_la_pct  1211 non-null   float64
#  45  no_children_2011_la_pct            1211 non-null   float64
#  46  dependent_children_2011_la_pct     1211 non-null   float64
#  47  nondependent_children_2011_la_pct  1211 non-null   float64
#  48  retired_2001_pct                   1211 non-null   float64
#  49  student_2001_pct                   1211 non-null   float64
#  50  retired_2011_pct                   1211 non-null   float64
#  51  student_2011_pct                   1211 non-null   float64
#  52  retired_2001_la_pct                1211 non-null   float64
#  53  student_2001_la_pct                1211 non-null   float64
#  54  retired_2011_la_pct                1211 non-null   float64
#  55  student_2011_la_pct                1211 non-null   float64
#  56  migrants_2011_pct                  1211 non-null   float64
#  57  migrants_2001_la_pct               1211 non-null   float64
#  58  migrants_2011_la_pct               1211 non-null   float64
#  59  newlybuilt_sale_2001_pct           1211 non-null   float64
#  60  newlybuilt_sale_2011_pct           1211 non-null   float64
#  61  newlybuilt_sale_2001_la_pct        1211 non-null   float64
#  62  newlybuilt_sale_2011_la_pct        1211 non-null   float64
#  63  owned_2001_pct                     1211 non-null   float64
#  64  rented_2001_pct                    1211 non-null   float64
#  65  owned_2011_pct                     1211 non-null   float64
#  66  rented_2011_pct                    1211 non-null   float64
#  67  owned_2001_la_pct                  1211 non-null   float64
#  68  rented_2001_la_pct                 1211 non-null   float64
#  69  owned_2011_la_pct                  1211 non-null   float64
#  70  rented_2011_la_pct                 1211 non-null   float64
# dtypes: float64(54), int64(8), object(9)
# memory usage: 671.9+ KB

# %%
swandlondon_key['ratio_la_median_price_2001']=(swandlondon_key['median_price_2001']/swandlondon_key['median_price_2001_la'])
swandlondon_key['ratio_la_median_price_2011']=(swandlondon_key['median_price_2011']/swandlondon_key['median_price_2011_la'])
swandlondon_key['ratio_r_median_price_2001']=(swandlondon_key['median_price_2001']/swandlondon_key['median_price_2001_region'])
swandlondon_key['ratio_r_median_price_2011']=(swandlondon_key['median_price_2011']/swandlondon_key['median_price_2011_region'])

swandlondon_key['ratio_la_earnings_2001']=(swandlondon_key['earnings_2001_la']/swandlondon_key['earnings_2001_la'])
swandlondon_key['ratio_la_earnings_2011']=(swandlondon_key['earnings_2011']/swandlondon_key['earnings_2011_la'])
swandlondon_key['ratio_r_earnings_2001']=(swandlondon_key['earnings_2001_la']/swandlondon_key['earnings_2001_region'])
swandlondon_key['ratio_r_earnings_2011']=(swandlondon_key['earnings_2011']/swandlondon_key['earnings_2011_region'])

swandlondon_key['ratio_la_nssec_2001']=(swandlondon_key['NS-SeC_higher_2001_pct']/swandlondon_key['NS-SeC_higher_2001_la_pct'])
swandlondon_key['ratio_la_nssec_2011']=(swandlondon_key['NS-SeC_higher_2011_pct']/swandlondon_key['NS-SeC_higher_2011_la_pct'])
swandlondon_key['ratio_r_nssec_2001']=(swandlondon_key['NS-SeC_higher_2001_pct']/swandlondon_key['NS-SeC_higher_2001_region_pct'])
swandlondon_key['ratio_r_nssec_2011']=(swandlondon_key['NS-SeC_higher_2011_pct']/swandlondon_key['NS-SeC_higher_2011_region_pct'])

swandlondon_key['ratio_la_qualification_2001']=(swandlondon_key['qualification_2001_pct']/swandlondon_key['qualification_2001_la_pct'])
swandlondon_key['ratio_la_qualification_2011']=(swandlondon_key['qualification_2011_pct']/swandlondon_key['qualification_2011_la_pct'])
swandlondon_key['ratio_r_qualification_2001']=(swandlondon_key['qualification_2001_pct']/swandlondon_key['qualification_2001_region_pct'])
swandlondon_key['ratio_r_qualification_2011']=(swandlondon_key['qualification_2011_pct']/swandlondon_key['qualification_2011_region_pct'])

# %%
for name in ['space_vacant', 'no_children', 'dependent_children','nondependent_children', 'retired', 'student', 'newlybuilt_sale','owned', 'rented']:
    for ind, row in swandlondon_key.iterrows():
        swandlondon_key.loc[ind,'ratio_la_'+name+'_2001'] = row[name + '_2001_pct']/row[name + '_2001_la_pct']
        swandlondon_key.loc[ind,'ratio_la_'+name+'_2011'] = row[name + '_2011_pct']/row[name + '_2011_la_pct']
        
#code reference: https://www.youtube.com/watch?v=nH1gw-slnOo

# %%
swandlondon_key['ratio_la_migrants_2001']=(swandlondon_key['migrants_2001_la_pct']/swandlondon_key['migrants_2001_la_pct'])
swandlondon_key['ratio_la_migrants_2011']=(swandlondon_key['migrants_2011_pct']/swandlondon_key['migrants_2011_la_pct'])

# %%
swandlondon_key.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1211 entries, 0 to 1210
# Data columns (total 107 columns):
#  #   Column                               Dtype
# ---  ------                               -----
#  0   MSOA11CD                             object
#  1   MSOA11NM                             object
#  2   LAD11CD                              object
#  3   LAD11NM                              object
#  4   RGN11CD                              object
#  5   RGN11NM                              object
#  6   MSOA01CD                             object
#  7   MSOA01NM                             object
#  8   CHGIND                               object
#  9   median_price_2001                    float64
#  10  median_price_2011                    int64
#  11  median_price_2001_la                 int64
#  12  median_price_2011_la                 int64
#  13  median_price_2001_region             int64
#  14  median_price_2011_region             int64
#  15  earnings_2011                        float64
#  16  earnings_2001_la                     int64
#  17  earnings_2011_la                     float64
#  18  earnings_2001_region                 int64
#  19  earnings_2011_region                 int64
#  20  NS-SeC_higher_2001_pct               float64
#  21  NS-SeC_higher_2011_pct               float64
#  22  NS-SeC_higher_2001_la_pct            float64
#  23  NS-SeC_higher_2011_la_pct            float64
#  24  NS-SeC_higher_2001_region_pct        float64
#  25  NS-SeC_higher_2011_region_pct        float64
#  26  qualification_2001_pct               float64
#  27  qualification_2011_pct               float64
#  28  qualification_2001_la_pct            float64
#  29  qualification_2011_la_pct            float64
#  30  qualification_2001_region_pct        float64
#  31  qualification_2011_region_pct        float64
#  32  space_vacant_2001_pct                float64
#  33  space_vacant_2011_pct                float64
#  34  space_vacant_2001_la_pct             float64
#  35  space_vacant_2011_la_pct             float64
#  36  no_children_2001_pct                 float64
#  37  dependent_children_2001_pct          float64
#  38  nondependent_children_2001_pct       float64
#  39  no_children_2011_pct                 float64
#  40  dependent_children_2011_pct          float64
#  41  nondependent_children_2011_pct       float64
#  42  no_children_2001_la_pct              float64
#  43  dependent_children_2001_la_pct       float64
#  44  nondependent_children_2001_la_pct    float64
#  45  no_children_2011_la_pct              float64
#  46  dependent_children_2011_la_pct       float64
#  47  nondependent_children_2011_la_pct    float64
#  48  retired_2001_pct                     float64
#  49  student_2001_pct                     float64
#  50  retired_2011_pct                     float64
#  51  student_2011_pct                     float64
#  52  retired_2001_la_pct                  float64
#  53  student_2001_la_pct                  float64
#  54  retired_2011_la_pct                  float64
#  55  student_2011_la_pct                  float64
#  56  migrants_2011_pct                    float64
#  57  migrants_2001_la_pct                 float64
#  58  migrants_2011_la_pct                 float64
#  59  newlybuilt_sale_2001_pct             float64
#  60  newlybuilt_sale_2011_pct             float64
#  61  newlybuilt_sale_2001_la_pct          float64
#  62  newlybuilt_sale_2011_la_pct          float64
#  63  owned_2001_pct                       float64
#  64  rented_2001_pct                      float64
#  65  owned_2011_pct                       float64
#  66  rented_2011_pct                      float64
#  67  owned_2001_la_pct                    float64
#  68  rented_2001_la_pct                   float64
#  69  owned_2011_la_pct                    float64
#  70  rented_2011_la_pct                   float64
#  71  ratio_la_median_price_2001           float64
#  72  ratio_la_median_price_2011           float64
#  73  ratio_r_median_price_2001            float64
#  74  ratio_r_median_price_2011            float64
#  75  ratio_la_earnings_2001               float64
#  76  ratio_la_earnings_2011               float64
#  77  ratio_r_earnings_2001                float64
#  78  ratio_r_earnings_2011                float64
#  79  ratio_la_nssec_2001                  float64
#  80  ratio_la_nssec_2011                  float64
#  81  ratio_r_nssec_2001                   float64
#  82  ratio_r_nssec_2011                   float64
#  83  ratio_la_qualification_2001          float64
#  84  ratio_la_qualification_2011          float64
#  85  ratio_r_qualification_2001           float64
#  86  ratio_r_qualification_2011           float64
#  87  ratio_la_space_vacant_2001           float64
#  88  ratio_la_space_vacant_2011           float64
#  89  ratio_la_no_children_2001            float64
#  90  ratio_la_no_children_2011            float64
#  91  ratio_la_dependent_children_2001     float64
#  92  ratio_la_dependent_children_2011     float64
#  93  ratio_la_nondependent_children_2001  float64
#  94  ratio_la_nondependent_children_2011  float64
#  95  ratio_la_retired_2001                float64
#  96  ratio_la_retired_2011                float64
#  97  ratio_la_student_2001                float64
#  98  ratio_la_student_2011                float64
#  99  ratio_la_newlybuilt_sale_2001        float64
#  100 ratio_la_newlybuilt_sale_2011        float64
#  101 ratio_la_owned_2001                  float64
#  102 ratio_la_owned_2011                  float64
#  103 ratio_la_rented_2001                 float64
#  104 ratio_la_rented_2011                 float64
#  105 ratio_la_migrants_2001               float64
#  106 ratio_la_migrants_2011               float64
# dtypes: float64(90), int64(8), object(9)
# memory usage: 1012.4+ KB

# %%
# get a list of the column names of all the columns that contain ratio information
ratio_cols = [col for col in swandlondon_key.columns if 'ratio' in col]

# get a list of the column names of several columns at the front
head_cols=list(swandlondon_key.iloc[:,0:9].columns)

#get a list of column names to help extract a subdataset contains all the columns that is essential for duther analysis
extract_cols2=head_cols+ratio_cols

print(extract_cols2)
# Out:
# ['MSOA11CD', 'MSOA11NM', 'LAD11CD', 'LAD11NM', 'RGN11CD', 'RGN11NM', 'MSOA01CD', 'MSOA01NM', 'CHGIND', 'ratio_la_median_price_2001', 'ratio_la_median_price_2011', 'ratio_r_median_price_2001', 'ratio_r_median_price_2011', 'ratio_la_earnings_2001', 'ratio_la_earnings_2011', 'ratio_r_earnings_2001', 'ratio_r_earnings_2011', 'ratio_la_nssec_2001', 'ratio_la_nssec_2011', 'ratio_r_nssec_2001', 'ratio_r_nssec_2011', 'ratio_la_qualification_2001', 'ratio_la_qualification_2011', 'ratio_r_qualification_2001', 'ratio_r_qualification_2011', 'ratio_la_space_vacant_2001', 'ratio_la_space_vacant_2011', 'ratio_la_no_children_2001', 'ratio_la_no_children_2011', 'ratio_la_dependent_children_2001', 'ratio_la_dependent_children_2011', 'ratio_la_nondependent_children_2001', 'ratio_la_nondependent_children_2011', 'ratio_la_retired_2001', 'ratio_la_retired_2011', 'ratio_la_student_2001', 'ratio_la_student_2011', 'ratio_la_newlybuilt_sale_2001', 'ratio_la_newlybuilt_sale_2011', 'ratio_la_owned_2001', 'ratio_la_owned_2011', 'ratio_la_rented_2001', 'ratio_la_rented_2011', 'ratio_la_migrants_2001', 'ratio_la_migrants_2011']

# %%
swandlondon_core=swandlondon_key[extract_cols2].copy()

# %% [markdown]
# 'swandlondon_core'only contains all the 'ratio variables'

# %%
swandlondon_core.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1211 entries, 0 to 1210
# Data columns (total 45 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   MSOA11CD                             1211 non-null   object
#  1   MSOA11NM                             1211 non-null   object
#  2   LAD11CD                              1211 non-null   object
#  3   LAD11NM                              1211 non-null   object
#  4   RGN11CD                              1211 non-null   object
#  5   RGN11NM                              1211 non-null   object
#  6   MSOA01CD                             1211 non-null   object
#  7   MSOA01NM                             1211 non-null   object
#  8   CHGIND                               1211 non-null   object
#  9   ratio_la_median_price_2001           1211 non-null   float64
#  10  ratio_la_median_price_2011           1211 non-null   float64
#  11  ratio_r_median_price_2001            1211 non-null   float64
#  12  ratio_r_median_price_2011            1211 non-null   float64
#  13  ratio_la_earnings_2001               1211 non-null   float64
#  14  ratio_la_earnings_2011               1211 non-null   float64
#  15  ratio_r_earnings_2001                1211 non-null   float64
#  16  ratio_r_earnings_2011                1211 non-null   float64
#  17  ratio_la_nssec_2001                  1211 non-null   float64
#  18  ratio_la_nssec_2011                  1211 non-null   float64
#  19  ratio_r_nssec_2001                   1211 non-null   float64
#  20  ratio_r_nssec_2011                   1211 non-null   float64
#  21  ratio_la_qualification_2001          1211 non-null   float64
#  22  ratio_la_qualification_2011          1211 non-null   float64
#  23  ratio_r_qualification_2001           1211 non-null   float64
#  24  ratio_r_qualification_2011           1211 non-null   float64
#  25  ratio_la_space_vacant_2001           1211 non-null   float64
#  26  ratio_la_space_vacant_2011           1211 non-null   float64
#  27  ratio_la_no_children_2001            1211 non-null   float64
#  28  ratio_la_no_children_2011            1211 non-null   float64
#  29  ratio_la_dependent_children_2001     1211 non-null   float64
#  30  ratio_la_dependent_children_2011     1211 non-null   float64
#  31  ratio_la_nondependent_children_2001  1211 non-null   float64
#  32  ratio_la_nondependent_children_2011  1211 non-null   float64
#  33  ratio_la_retired_2001                1211 non-null   float64
#  34  ratio_la_retired_2011                1211 non-null   float64
#  35  ratio_la_student_2001                1211 non-null   float64
#  36  ratio_la_student_2011                1211 non-null   float64
#  37  ratio_la_newlybuilt_sale_2001        1211 non-null   float64
#  38  ratio_la_newlybuilt_sale_2011        1211 non-null   float64
#  39  ratio_la_owned_2001                  1211 non-null   float64
#  40  ratio_la_owned_2011                  1211 non-null   float64
#  41  ratio_la_rented_2001                 1211 non-null   float64
#  42  ratio_la_rented_2011                 1211 non-null   float64
#  43  ratio_la_migrants_2001               1211 non-null   float64
#  44  ratio_la_migrants_2011               1211 non-null   float64
# dtypes: float64(36), object(9)
# memory usage: 425.9+ KB

# %%
swandlondon_core.to_csv('output/swandlondon_core.csv',index=False)
